# %% [markdown]
# <a href="https://colab.research.google.com/github/kinanpermata/PCVK-Genap-20-21/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# Joko Widodo
jokowi = cv.imread('/content/drive/MyDrive/PVCK/jokowi.jpg')
jokowi_detect = cv.imread('/content/drive/MyDrive/PVCK/jokowi.jpg')

def convertToRGB(image):
    return cv.cvtColor(image, cv.COLOR_BGR2RGB)

cascade_face = cv.CascadeClassifier('/content/drive/MyDrive/PVCK/haarcascade_frontalface_alt.xml')

faces_rects = cascade_face.detectMultiScale(jokowi_detect, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(jokowi_detect, (x, y), (x+w, y+h), (0, 255, 0), 5)

f, axarr = plt. subplots(6,2,figsize=(15,10))
plt.subplot(321),plt.imshow(convertToRGB(jokowi))
plt.subplot(322),plt.imshow(convertToRGB(jokowi_detect))

# RA Kartini
kartini = cv.imread('/content/drive/MyDrive/PVCK/kartini.jpg')
kartini_detect = cv.imread('/content/drive/MyDrive/PVCK/kartini.jpg')

cascade_face = cv.CascadeClassifier('/content/drive/MyDrive/PVCK/haarcascade_frontalface_alt.xml')

faces_rects = cascade_face.detectMultiScale(kartini_detect, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(kartini_detect, (x, y), (x+w, y+h), (0, 255, 0), 5)

plt.subplot(323),plt.imshow(convertToRGB(kartini))
plt.subplot(324),plt.imshow(convertToRGB(kartini_detect))

# Kucing
kucing = cv.imread('/content/drive/MyDrive/PVCK/kucing.jpg')
kucing_detect = cv.imread('/content/drive/MyDrive/PVCK/kucing.jpg')

faces_rects = faceCascade.detectMultiScale(kucing_detect, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(kucing_detect, (x, y), (x+w, y+h), (0, 255, 0), 5)

plt.subplot(325),plt.imshow(convertToRGB(kucing))
plt.subplot(326),plt.imshow(convertToRGB(kucing_detect))

# Masker
masker = cv.imread('/content/drive/MyDrive/PVCK/mask.png')
masker_detect = cv.imread('/content/drive/MyDrive/PVCK/mask.png')

faces_rects = faceCascade.detectMultiScale(masker_detect, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(masker_detect, (x, y), (x+w, y+h), (0, 255, 0), 5)

f, axarr = plt. subplots(6,2,figsize=(15,10))
plt.subplot(321),plt.imshow(convertToRGB(masker))
plt.subplot(322),plt.imshow(convertToRGB(masker_detect))

# Michael Jordan
mJordan = cv.imread('/content/drive/MyDrive/PVCK/mjordan.jpg')
mJordan_detect = cv.imread('/content/drive/MyDrive/PVCK/mjordan.jpg')

faces_rects = faceCascade.detectMultiScale(mJordan_detect, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(mJordan_detect, (x, y), (x+w, y+h), (0, 255, 0), 3)

plt.subplot(323),plt.imshow(convertToRGB(mJordan))
plt.subplot(324),plt.imshow(convertToRGB(mJordan_detect))

# Solvayconf
solv = cv.imread('/content/drive/MyDrive/PVCK/solvayconf.jpg')
solv_detect = cv.imread('/content/drive/MyDrive/PVCK/solvayconf.jpg')

faces_rects = faceCascade.detectMultiScale(solv_detect, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(solv_detect, (x, y), (x+w, y+h), (0, 255, 0), 3)

plt.subplot(325),plt.imshow(convertToRGB(solv))
plt.subplot(326),plt.imshow(convertToRGB(solv_detect))
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f9d1881a290>,
#  <matplotlib.image.AxesImage at 0x7f9d187fad10>)

# %%
cascade_face = cv.CascadeClassifier('/content/drive/MyDrive/PVCK/haarcascade_frontalcatface.xml')

kucing = cv.imread('/content/drive/MyDrive/PVCK/kucing.jpg', 0)
kucing_detect = cv.imread('/content/drive/MyDrive/PVCK/kucing.jpg', 0)

detection  = cascade_face.detectMultiScale(kucing_detect)
for (x,y,w,h) in detection : 
  cv.rectangle(kucing_detect,(x,y),(x+w,y+h),(0,255,0),1) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kucing, cmap='gray')
plt.subplot(122),plt.imshow(kucing_detect, cmap='gray')
plt.show()

# %%
cascade_face = cv.CascadeClassifier('/content/drive/MyDrive/PVCK/haarcascade_eye.xml') 

jokowi = cv.imread('/content/drive/MyDrive/PVCK/jokowi.jpg')
jokowi_ori = cv.imread('/content/drive/MyDrive/PVCK/jokowi.jpg')
jokowi_gray = cv.cvtColor(jokowi, cv.COLOR_BGR2GRAY)
jokowi_origray = cv.cvtColor(jokowi_ori, cv.COLOR_BGR2GRAY)

detection = cascade_face.detectMultiScale(jokowi_gray)
for (x,y,w,h) in detection: 
  cv.rectangle(jokowi_gray,(x,y),(x+w,y+h),(255,255,255),1)

# Plot Outputs
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121),plt.imshow(jokowi_origray, cmap='gray')
plt.subplot(122),plt.imshow(jokowi_gray, cmap='gray')
plt.show()

# %%
mJordan = cv.imread('/content/drive/MyDrive/PVCK/mjordan.jpg') 
mJordan_gray = cv.cvtColor(mJordan, cv.COLOR_BGR2GRAY) 
figure_size = 9 

output = cv.medianBlur(mJordan_gray, figure_size)
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121), plt.imshow(mJordan_gray, cmap='gray'),plt.title('Original')
plt.subplot(122), plt.imshow(output, cmap='gray'),plt.title('Median Filter')
plt.show()
